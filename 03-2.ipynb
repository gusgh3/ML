# %%
import pandas as pd

# %%
df = pd.read_csv('data/Fish.csv')

# %%
cond = df['Species'] == 'Perch'

perch_length = df.loc[cond, ['Length2']]
perch_weight = df.loc[cond, ['Weight']]

perch_length
# Out:
#      Length2
# 72       8.4
# 73      13.7
# 74      15.0
# 75      16.2
# 76      17.4
# 77      18.0
# 78      18.7
# 79      19.0
# 80      19.6
# 81      20.0
# 82      21.0
# 83      21.0
# 84      21.0
# 85      21.3
# 86      22.0
# 87      22.0
# 88      22.0
# 89      22.0
# 90      22.0
# 91      22.5
# 92      22.5
# 93      22.7
# 94      23.0
# 95      23.5
# 96      24.0
# 97      24.0
# 98      24.6
# 99      25.0
# 100     25.6
# 101     26.5
# 102     27.3
# 103     27.5
# 104     27.5
# 105     27.5
# 106     28.0
# 107     28.7
# 108     30.0
# 109     32.8
# 110     34.5
# 111     35.0
# 112     36.5
# 113     36.0
# 114     37.0
# 115     37.0
# 116     39.0
# 117     39.0
# 118     39.0
# 119     40.0
# 120     40.0
# 121     40.0
# 122     40.0
# 123     42.0
# 124     43.0
# 125     43.0
# 126     43.5
# 127     44.0

# %%
from sklearn.model_selection import train_test_split

# %%
train_input, test_input, train_target, test_target = train_test_split(
    perch_length, perch_weight, random_state=100)

# %%
test_input.head()
# Out:
#      Length2
# 105     27.5
# 78      18.7
# 124     43.0
# 121     40.0
# 84      21.0

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(train_input, train_target)
# Out:
# LinearRegression()

# %%
lr.score(test_input, test_target)
# Out:
# 0.8854159312228587

# %%
lr.predict([[100]])
# Out:
# C:\Users\2-10\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3117.99371211]])

# %%
a = lr.coef_[0][0]
a
# Out:
# np.float64(38.052388445444635)

# %%
b = lr.intercept_[0]
b
# Out:
# np.float64(-687.2451324388538)

# %%
import matplotlib.pyplot as plt

plt.scatter(train_input['Length2'], train_target['Weight'])
plt.plot([10, 50], [10*a + b, 50*a + b])
plt.show()

# %%
perch_length.head()
# Out:
#     Length2
# 72      8.4
# 73     13.7
# 74     15.0
# 75     16.2
# 76     17.4

# %%
train_input['Length2_poly'] = train_input['Length2']**2
test_input['Length2_poly'] = test_input['Length2']**2

# %%
test_input.head()
# Out:
#      Length2  Length2_poly
# 105     27.5        756.25
# 78      18.7        349.69
# 124     43.0       1849.00
# 121     40.0       1600.00
# 84      21.0        441.00

# %%
lr = LinearRegression()
lr.fit(train_input, train_target)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[-26.99656509,   1.10288319]])

# %%
lr.intercept_
# Out:
# array([190.60650828])

# %%
lr.predict([[60, 60**2]])
# Out:
# C:\Users\2-10\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2541.19208279]])

# %%
lr.score(test_input, test_target)
# Out:
# 0.9728102367657678

# %%
#import matplotlib.pyplot as plt
 

#plt.scatter(train_input['Length2'], train_target['Weight'])
#plt.plot([10, 50], [10*a + b, 50*a + b])
#plt.plot()
#plt.show()
